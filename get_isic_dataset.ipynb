# %%
use_gdrive = True

# %%
import os
from tqdm import tqdm

if use_gdrive:
  from google.colab import drive
  drive.mount('/content/drive')

data_dir = "/content/drive/MyDrive/CV_Final_Project"
isic_dataset_dir = data_dir + '/isic_dataset'

os.makedirs(isic_dataset_dir, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install kaggle
# !mkdir ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json
# %cd /content/drive/MyDrive/🦫/Classes/CV Final Project/isic_dataset
# !kaggle competitions download -c siim-isic-melanoma-classification

# %%
# !wget https://isic-challenge-data.s3.amazonaws.com/2020/ISIC_2020_Training_JPEG.zip -O {isic_dataset_dir}/train.zip
# !wget https://isic-challenge-data.s3.amazonaws.com/2020/ISIC_2020_Training_GroundTruth.csv -O {isic_dataset_dir}/truth.csv
# !wget https://isic-challenge-data.s3.amazonaws.com/2020/ISIC_2020_Test_JPEG.zip -O {isic_dataset_dir}/test.zip

# !unzip -o {isic_dataset_dir}'/train.zip' -d {isic_dataset_dir}
# !unzip -o {isic_dataset_dir}'/test.zip' -d {isic_dataset_dir}
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/CV_Final_Project/isic_dataset/ISIC_2020_Test_Input/ISIC_1997899.jpg
#   inflating: /content/drive/MyDrive/CV_Final_Project/isic_dataset/ISIC_2020_Test_Input/ISIC_6690278.jpg
#   inflating: /content/drive/MyDrive/CV_Final_Project/isic_dataset/ISIC_2020_Test_Input/ISIC_1392557.jpg
#   inflating: /content/drive/MyDrive/CV_Final_Project/isic_dataset/ISIC_2020_Test_Input/ISIC_5467877.jpg
#   inflating: /content/drive/MyDrive/CV_Final_Project/isic_dataset/ISIC_2020_Test_Input/ISIC_0665521.jpg
#   inflating: /content/drive/MyDrive/CV_Final_Project/isic_dataset/ISIC_2020_Test_Input/ISIC_9802201.jpg
#   inflating: /content/drive/MyDrive/CV_Final_Project/isic_dataset/ISIC_2020_Test_Input/ISIC_5664143.jpg
#   inflating: /content/drive/MyDrive/CV_Final_Project/isic_dataset/ISIC_2020_Test_Input/ISIC_4341449.jpg
# ...

# %%
# %ls
# Out:
# drive/  sample_data/
